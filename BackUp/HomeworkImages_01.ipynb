# %%
import os
import tensorflow as tf
import numpy as np
import json

SEED = 1234
tf.random.set_seed(SEED)

# %%
#Creation of data generator objects

from tensorflow.keras.preprocessing.image import ImageDataGenerator

apply_data_augmentation = True

if apply_data_augmentation:
    train_data_gen = ImageDataGenerator(rotation_range=10,
                                       width_shift_range=10,
                                       height_shift_range=10,
                                       zoom_range=0.3,
                                       horizontal_flip=True,
                                       vertical_flip=True,
                                       fill_mode='constant',#when we flip, rotate, we introduce new pixels and we must set a way on how to fill
                                       cval=0,
                                       rescale=1/255.)

else:
    train_data_gen = ImageDataGenerator(rescale=1/255.)
    
valid_data_gen = ImageDataGenerator(rescale=1/255.)

# %%
#Setting paths for training, validation and test set

cwd = os.path.join(os.path.dirname(os.getcwd()),"artificial-neural-networks-and-deep-learning-2020/MaskDataset/")

dataset_dir = os.path.join(cwd, "training/")
validation_dir = os.path.join(cwd, "validation/")
test_dir = os.path.join(cwd, "test/")

# %% [markdown]
# path = os.getcwd()
# print ("The current working directory is %s" % test_dir)

# %% [markdown]
# with open(os.path.join(cwd,'train_gt.json')) as f:
#   myJson = json.load(f)
# print(myJson)

# %% [markdown]
# #division of images in different set
#
# for key in myJson:
#     os.rename(os.path.join(dataset_dir,key), dataset_dir+'/'+str(myJson[key])+'/'+key)

# %%
#Generators for reading images dirrectly from directories

img_h = 408
img_w = 612

bs=16

#training generator
train_gen = train_data_gen.flow_from_directory(dataset_dir,
                                               target_size=(img_h,img_w),
                                              color_mode='rgb',
                                              batch_size=bs,
                                              class_mode='categorical',
                                              shuffle=True,
                                              seed=SEED)
#validation generator
valid_gen = valid_data_gen.flow_from_directory(validation_dir,
                                               target_size=(img_h,img_w),
                                               color_mode='rgb',
                                              batch_size=bs,
                                              class_mode='categorical',
                                              shuffle=True,
                                              seed=SEED)
# Out:
# Found 5290 images belonging to 3 classes.
# Found 324 images belonging to 3 classes.

# %%
#creation of dataset objects
num_classes = 3


train_dataset = tf.data.Dataset.from_generator(lambda: train_gen,
                                              output_types=(tf.float32,tf.float32),
                                              output_shapes=([None,img_h,img_w,3],[None,num_classes]))

train_dataset=train_dataset.repeat()

valid_dataset = tf.data.Dataset.from_generator(lambda: valid_gen,
                                              output_types=(tf.float32,tf.float32),
                                              output_shapes=([None,img_h,img_w,3],[None,num_classes]))

valid_dataset=valid_dataset.repeat()

# %%
import matplotlib.pyplot as plt

iterator = iter(train_dataset)

# %%
augmented_img, target = next(iterator)
augmented_img = np.array(augmented_img[0])
augmented_img = augmented_img * 255

plt.imshow(np.uint8(augmented_img))
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
start_f = 9
depth = 6

model = tf.keras.Sequential()
for i in range(depth):
    if i == 0:
        input_shape = [img_h,img_w,3]
    else:
        input_shape = [None]
    
    model.add(tf.keras.layers.Conv2D(filters=start_f,
                                    kernel_size=(3,3),
                                    strides=(1,1),
                                    padding='same',
                                    input_shape=input_shape))
    model.add(tf.keras.layers.ReLU())
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
    start_f *=2
    
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=1024, activation='relu'))
model.add(tf.keras.layers.Dense(units=512, activation='relu'))

model.add(tf.keras.layers.Dense(units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_77 (Conv2D)           (None, 408, 612, 9)       252
# _________________________________________________________________
# re_lu_77 (ReLU)              (None, 408, 612, 9)       0
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 204, 306, 9)       0
# _________________________________________________________________
# conv2d_78 (Conv2D)           (None, 204, 306, 18)      1476
# _________________________________________________________________
# re_lu_78 (ReLU)              (None, 204, 306, 18)      0
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 102, 153, 18)      0
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 102, 153, 36)      5868
# _________________________________________________________________
# re_lu_79 (ReLU)              (None, 102, 153, 36)      0
# _________________________________________________________________
# max_pooling2d_79 (MaxPooling (None, 51, 76, 36)        0
# _________________________________________________________________
# conv2d_80 (Conv2D)           (None, 51, 76, 72)        23400
# _________________________________________________________________
# re_lu_80 (ReLU)              (None, 51, 76, 72)        0
# _________________________________________________________________
# max_pooling2d_80 (MaxPooling (None, 25, 38, 72)        0
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 25, 38, 144)       93456
# _________________________________________________________________
# re_lu_81 (ReLU)              (None, 25, 38, 144)       0
# _________________________________________________________________
# max_pooling2d_81 (MaxPooling (None, 12, 19, 144)       0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 12, 19, 288)       373536
# _________________________________________________________________
# re_lu_82 (ReLU)              (None, 12, 19, 288)       0
# _________________________________________________________________
# max_pooling2d_82 (MaxPooling (None, 6, 9, 288)         0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 15552)             0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1024)              15926272
# _________________________________________________________________
# dense_33 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_34 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 16,950,599
# Trainable params: 16,950,599
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Loss function
loss = tf.keras.losses.CategoricalCrossentropy()

#Learning rate
lr = 1e-4
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

#Validation metric used during training
metrics = ['accuracy']

model.compile(optimizer=optimizer, loss=loss , metrics=metrics)

# %%
#Callbacks list

from datetime import datetime

exps_dir = os.path.join(cwd, 'classification_experiments_')
if not os.path.exists(exps_dir):
    os.makedirs(exps_dir)

now = datetime.now().strftime('%b%d_%H-%M-%S')

exp_name='FC'

exp_dir = os.path.join(exps_dir, exp_name + '_' + str(now))
if not os.path.exists(exp_dir):
    os.makedirs(exp_dir)
    
callbacks = []

ckpt_dir = os.path.join(exp_dir, 'ckpts')
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)

#Checkpoint callback
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir,'cp.ckpt'),save_weights_only=True)

callbacks.append(ckpt_callback)

#tensorboard callback
tb_dir = os.path.join(exp_dir, 'tb_logs')
if not os.path.exists(tb_dir):
    os.makedirs(tb_dir)
tb_callback=tf.keras.callbacks.TensorBoard(log_dir=tb_dir,histogram_freq=1)


# By default shows losses and metrics for both training and validation
tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir,
                                             profile_batch=0,
                                             histogram_freq=1)  # if 1 shows weights histograms
callbacks.append(tb_callback)

# Early Stopping
# --------------
early_stop = True
if early_stop:
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    callbacks.append(es_callback)

# %%
#model.load_weights(filepath=os.path.join(cwd,'cp.ckpt'))


model.fit(x=train_dataset,
         epochs=100,
         steps_per_epoch=len(train_gen),
        validation_data=valid_dataset,
         validation_steps=len(valid_gen),
         callbacks=callbacks)
# Out:
# Train for 331 steps, validate for 21 steps
# Epoch 1/100
# 331/331 [==============================] - 266s 802ms/step - loss: 0.9148 - accuracy: 0.5446 - val_loss: 0.8072 - val_accuracy: 0.5864
# Epoch 2/100
# 331/331 [==============================] - 267s 806ms/step - loss: 0.7859 - accuracy: 0.6234 - val_loss: 0.7523 - val_accuracy: 0.6420
# Epoch 3/100
# 331/331 [==============================] - 271s 818ms/step - loss: 0.7170 - accuracy: 0.6505 - val_loss: 0.6756 - val_accuracy: 0.6790
# Epoch 4/100
# 331/331 [==============================] - 281s 848ms/step - loss: 0.6836 - accuracy: 0.6679 - val_loss: 0.6099 - val_accuracy: 0.7377
# Epoch 5/100
# 331/331 [==============================] - 267s 805ms/step - loss: 0.6389 - accuracy: 0.6921 - val_loss: 0.5809 - val_accuracy: 0.7346
# Epoch 6/100
# 331/331 [==============================] - 266s 803ms/step - loss: 0.6155 - accuracy: 0.7032 - val_loss: 0.5862 - val_accuracy: 0.7160
# Epoch 7/100
# 331/331 [==============================] - 271s 817ms/step - loss: 0.5841 - accuracy: 0.7233 - val_loss: 0.5483 - val_accuracy: 0.7562
# Epoch 8/100
# 331/331 [==============================] - 275s 830ms/step - loss: 0.5846 - accuracy: 0.7238 - val_loss: 0.7161 - val_accuracy: 0.6512
# Epoch 9/100
# 331/331 [==============================] - 271s 819ms/step - loss: 0.5461 - accuracy: 0.7442 - val_loss: 0.5868 - val_accuracy: 0.7130
# Epoch 10/100
# 331/331 [==============================] - 271s 819ms/step - loss: 0.5334 - accuracy: 0.7561 - val_loss: 0.5699 - val_accuracy: 0.7130
# Epoch 11/100
# 331/331 [==============================] - 266s 803ms/step - loss: 0.5163 - accuracy: 0.7618 - val_loss: 0.4735 - val_accuracy: 0.7778
# Epoch 12/100
# 331/331 [==============================] - 258s 778ms/step - loss: 0.3446 - accuracy: 0.8461 - val_loss: 0.6521 - val_accuracy: 0.7438
# Epoch 32/100
# 331/331 [==============================] - 260s 785ms/step - loss: 0.3508 - accuracy: 0.8486 - val_loss: 0.4807 - val_accuracy: 0.7932
# Epoch 33/100
# 331/331 [==============================] - 259s 782ms/step - loss: 0.3569 - accuracy: 0.8410 - val_loss: 0.4767 - val_accuracy: 0.7778
# Epoch 34/100
# 331/331 [==============================] - 261s 789ms/step - loss: 0.3325 - accuracy: 0.8533 - val_loss: 0.4528 - val_accuracy: 0.7963
# Epoch 35/100
# 331/331 [==============================] - 260s 787ms/step - loss: 0.3353 - accuracy: 0.8509 - val_loss: 0.4217 - val_accuracy: 0.8302
# Epoch 36/100
# 331/331 [==============================] - 260s 785ms/step - loss: 0.3286 - accuracy: 0.8577 - val_loss: 0.4960 - val_accuracy: 0.7963
# Epoch 37/100
# 331/331 [==============================] - 257s 776ms/step - loss: 0.3069 - accuracy: 0.8629 - val_loss: 0.4854 - val_accuracy: 0.7994
# Epoch 38/100
# 331/331 [==============================] - 258s 779ms/step - loss: 0.3223 - accuracy: 0.8554 - val_loss: 0.5471 - val_accuracy: 0.7562
# Epoch 39/100
# 331/331 [==============================] - 255s 771ms/step - loss: 0.3060 - accuracy: 0.8737 - val_loss: 0.4263 - val_accuracy: 0.8086
# Epoch 40/100
# 331/331 [==============================] - 257s 776ms/step - loss: 0.2912 - accuracy: 0.8737 - val_loss: 0.4378 - val_accuracy: 0.8210

# %%
#Function for creating the result in a csv file

from datetime import datetime

def create_csv(results, results_dir='./results'):

    csv_fname = 'results_'
    csv_fname += datetime.now().strftime('%b%d_%H-%M-%S') + '.csv'

    with open(os.path.join(results_dir, csv_fname), 'w') as f:

        f.write('Id,Category\n')

        for key, value in results.items():
            f.write(key + ',' + str(value) + '\n')

# %%
#Prediction computation done one image at time

from PIL import Image

image_filenames = next(os.walk(test_dir))[2]

results = {}
for image_name in image_filenames:
    
    image = tf.keras.preprocessing.image.load_img(test_dir+image_name,target_size=(img_h,img_w))
    input_arr = tf.keras.preprocessing.image.img_to_array(image)
    input_arr = np.array([input_arr])  # Convert single image to a batch.
    
    predictions = model.predict_classes(input_arr*(1/255))
    #img = Image.open(test_dir+'/'+image_name).convert('RGB')
    #img_array = np.array(img)
    #img_array = np.expand_dims(img_array, 0) 
    #data_normalization
    #print(np.argmax(predictions, axis=1)[0] )

    #prediction = argmax(softmax)   # predicted class
    

    #results[image_name] = np.argmax(predictions, axis=1) [0]
    
    results[image_name] = predictions[0]

create_csv(results)
print (results)
# Out:
# {'10001.jpg': 2, '10040.jpg': 2, '10074.jpg': 1, '10084.jpg': 1, '10100.jpg': 2, '10120.jpg': 2, '10125.jpg': 1, '10148.jpg': 1, '10213.jpg': 1, '10239.jpg': 2, '10242.jpg': 2, '10259.jpg': 1, '10289.jpg': 1, '10296.jpg': 0, '10323.jpg': 1, '10324.jpg': 0, '10326.jpg': 1, '10328.jpg': 0, '10330.jpg': 0, '10346.jpg': 0, '10349.jpg': 1, '10370.jpg': 1, '10382.jpg': 1, '10396.jpg': 1, '10411.jpg': 1, '10437.jpg': 2, '10459.jpg': 0, '10473.jpg': 1, '10477.jpg': 1, '10494.jpg': 0, '10520.jpg': 2, '10530.jpg': 1, '10571.jpg': 1, '10572.jpg': 1, '10581.jpg': 2, '10620.jpg': 0,
pg': 0, '13100.jpg': 1, '13107.jpg': 1, '13161.jpg': 1, '13219.jpg': 0, '13220.jpg': 1, '13273.jpg': 0, '13318.jpg': 2, '13322.jpg': 1, '13326.jpg': 1, '13344.jpg': 0, '13348.jpg': 2, '13373.jpg': 0, '13381.jpg': 1, '13392.jpg': 1, '13407.jpg': 0, '13475.jpg': 2, '13490.jpg': 0, '13503.jpg': 2, '13506.jpg': 0, '13524.jpg': 2, '13527.jpg': 0, '13536.jpg': 1, '13543.jpg': 1, '13554.jpg': 2, '13584.jpg': 2, '13617.jpg': 2, '13633.jpg': 0, '13656.jpg': 0, '13663.jpg': 0, '13693.jpg': 2, '13701.jpg': 1, '13710.jpg': 2, '13760.jpg': 1, '13818.jpg': 0, '13830.jpg': 1, '13870.jpg': 0, '13888.jpg': 0, '13892.jpg': 1, '13894.jpg': 2, '13911.jpg': 0, '13916.jpg': 2, '13926.jpg': 2, '13931.jpg': 2, '13938.jpg': 0, '13942.jpg': 2, '13974.jpg': 2, '13980.jpg': 2, '14014.jpg': 0, '14033.jpg': 2, '14077.jpg': 1, '14078.jpg': 1, '14094.jpg': 0, '14113.jpg': 0, '14120.jpg': 1, '14169.jpg': 1, '14175.jpg': 0, '14195.jpg': 0, '14199.jpg': 0, '14201.jpg': 2, '14207.jpg': 1, '14215.jpg': 1, '14217.jpg': 0, '14230.jpg': 1, '14264.jpg': 1, '14314.jpg': 2, '14327.jpg': 2, '14391.jpg': 2, '14403.jpg': 2, '14404.jpg': 1, '14412.jpg': 1, '14422.jpg': 1, '14435.jpg': 0, '14466.jpg': 2, '14491.jpg': 2, '14514.jpg': 2, ...

# %%
model.save_weights(filepath=os.path.join(cwd,'cp.ckpt'))

# %%
print(cwd)
# Out:
# C:/Users/ASUS/Documents/Università/ANNDL

# %%
image = tf.keras.preprocessing.image.load_img(test_dir+image_name,target_size=(img_h,img_w))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])*1/255
print(input_arr.shape)

#augmented_img = augmented_img * 255
print (input_arr)

plt.imshow(np.uint8(input_arr*255)[0])
plt.plot
# Out:
# (1, 408, 612, 3)
# [[[[0.06666667 0.03529412 0.02352941]
#    [0.06666667 0.03529412 0.02352941]
#    [0.07058824 0.04313726 0.01960784]
#    ...
#    [0.00392157 0.00392157 0.00392157]
#    [0.00392157 0.00392157 0.00392157]
#    [0.00392157 0.00392157 0.00392157]]
#
#   [[0.06666667 0.03529412 0.02352941]
#    [0.06666667 0.03921569 0.01568628]
#    [0.07058824 0.04313726 0.01960784]
#    ...
#    [0.00392157 0.00392157 0.00392157]
#    [0.00392157 0.00392157 0.00392157]
#    [0.00392157 0.00392157 0.00392157]]
#
#   [[0.06666667 0.03529412 0.02352941]
#    [0.07058824 0.04313726 0.01960784]
#    [0.07450981 0.04705882 0.02352941]
#    ...
#    [0.00392157 0.00392157 0.00392157]
#    [0.00392157 0.00392157 0.00392157]
#    [0.00392157 0.00392157 0.00392157]]
#
#   ...
#
#   [[0.00392157 0.00392157 0.        ]
#    [0.00392157 0.00392157 0.        ]
#    [0.00392157 0.00392157 0.        ]
#    ...
#    [0.20784314 0.06666667 0.00392157]
#    [0.20784314 0.06666667 0.00392157]
#    [0.20392157 0.0627451  0.        ]]
#
#   [[0.00392157 0.00392157 0.        ]
#    [0.00392157 0.00392157 0.        ]
#    [0.00392157 0.00392157 0.        ]
#    ...
#    [0.19607843 0.07450981 0.00392157]
#    [0.19215687 0.07058824 0.        ]
#    [0.1882353  0.06666667 0.        ]]
#
#   [[0.00392157 0.00392157 0.        ]
#    [0.00392157 0.00392157 0.        ]
#    [0.00392157 0.00392157 0.        ]
#    ...
#    [0.18039216 0.07450981 0.        ]
#    [0.18039216 0.07450981 0.        ]
#    [0.1764706  0.07058824 0.        ]]]]
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>
